# %%
from sklearn.datasets import make_regression
import numpy as np

# %%
X,y = make_regression(n_samples = 4 , n_features = 1 , n_informative = 1 , n_targets = 1 , noise = 80 , random_state = 13)

# %%
import matplotlib.pyplot as plt
plt.scatter(X,y)

# %%
from sklearn.linear_model import LinearRegression

# %%
reg = LinearRegression()
reg.fit(X,y)
# Out:
# LinearRegression()

# %%
reg.coef_
# Out:
# array([78.35063668])

# %%
reg.intercept_
# Out:
# np.float64(26.15963284313262)

# %%
plt.scatter(X,y)
plt.plot(X,reg.predict(X) , color = "red")

# %%
# m = 78
# b = 0

y_pred = ((78 * X) + 0).reshape(4)
y_pred
# Out:
# array([-55.56647164,  35.24136242,  -3.47124011,  58.79377754])

# %%
plt.scatter(X,y)
plt.plot(X,reg.predict(X),color = 'red',label = 'OLS')
plt.plot(X,y_pred,color = 'green',label = 'b = 0')
plt.legend()
plt.show()

# %%
m = 78
b = 0

loss_slope = -2 * np.sum(y - m*X.ravel() - b)
loss_slope
# Out:
# np.float64(-209.59171356600396)

# %%
# learning rate = 0.1

lr = 0.1

step_size = loss_slope * lr
step_size
# Out:
# np.float64(-20.959171356600397)

# %%
# calculate the new intercept 

b = b - step_size
b
# Out:
# np.float64(20.959171356600397)

# %%
y_pred1 = ((78 * X) + b).reshape(4)

plt.scatter(X,y)
plt.plot(X,reg.predict(X),color = 'red',label = 'OLS')
plt.plot(X,y_pred1,color = 'yellow',label = 'b = 20.959171356600397')
plt.plot(X,y_pred,color = 'green',label = 'b = 0')
plt.legend()
plt.show()

# %%
b = -100
m = 78.35
lr = 0.1

epochs = 10

for i in range(epochs):
    loss_slope = -2 * np.sum(y - m * X.ravel() - b)

    y_pred = m * X + b

    plt.plot(X,y_pred)

plt.scatter(X,y)
